# %% [markdown]
# # Contract Awards by  the Centers for Medicare and Medicaid Services (CMS)
# The dataset comes from https://www.usaspending.gov/#/download_center/custom_award_data using filters to select all Prime Awards types, Agency = Department of Health and Human Services, Sub Agency = Centers for Medicare and Medicaid Services, by All Recipient Location, by Action Date, for FY 2019.
# ## Data on Health and Human Services (HHS) CMS' contract awards for fiscal year (FY) 2019.
# In the spirit of transparency and full disclosure, the www.usaspending.gov site includes information about how federal dollars have been spent. Tools on the site allow members of the public to access data sets for their own evaluation or to filter and visualize data online. I am interested in seeing statistics about the contract awards in FY 2019, especially to see which contract award types garner the highest dollar awards, which types of work have the most number of proposals received (and which ones do not receive multiple proposals), and which award recipients came away with the biggest wins.

# %%
#import os
#os.getcwd() # gives the path of the current working directory (cwd)

# %%
import numpy as np
import pandas as pd
contracts = pd.read_csv('C:\\Users\\Jennifer\\Downloads\\FY2019HHSContractAwards.csv') # This reads in my csv file.
contracts.head() # This lists the first 5 rows of the dataframe with all of the columns (276).
# Out:
# C:\Users\Jennifer\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (21,63,159,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                      contract_transaction_unique_key  \
# 0  7530_7530_HHSM500T0016_P00004_HHSM500201400034I_0
# 1  7530_7530_HHSM500T0011_P00007_HHSM500200400007I_0
# 2  7530_7530_HHSM500T0016_P00006_HHSM500201400034I_0
# 3    7530_4732_HHSM500201700031G_P00006_GS35F328DA_0
# 4      7530_7530_75FCMC19F0002_0_HHSM500201600051I_0
#
#                            contract_award_unique_key      award_id_piid  \
# 0  CONT_AWD_HHSM500T0016_7530_HHSM500201400034I_7530       HHSM500T0016
# 1  CONT_AWD_HHSM500T0011_7530_HHSM500200400007I_7530       HHSM500T0011
# 2  CONT_AWD_HHSM500T0016_7530_HHSM500201400034I_7530       HHSM500T0016
# 3    CONT_AWD_HHSM500201700031G_7530_GS35F328DA_4732  HHSM500201700031G
# 4  CONT_AWD_75FCMC19F0002_7530_HHSM500201600051I_...      75FCMC19F0002
#
#   modification_number  transaction_number  parent_award_agency_id  \
# 0              P00004                 0.0                  7530.0
# 1              P00007                 0.0                  7530.0
# 2              P00006                 0.0                  7530.0
# 3              P00006                 0.0                  4732.0
# 4                   0                 0.0                  7530.0
#
#                      parent_award_agency_name parent_award_id_piid  \
# 0  CENTERS FOR MEDICARE AND MEDICAID SERVICES    HHSM500201400034I
# 1  CENTERS FOR MEDICARE AND MEDICAID SERVICES    HHSM500200400007I
# 2  CENTERS FOR MEDICARE AND MEDICAID SERVICES    HHSM500201400034I
# 3                 FEDERAL ACQUISITION SERVICE           GS35F328DA
# 4  CENTERS FOR MEDICARE AND MEDICAID SERVICES    HHSM500201600051I
#
#   parent_award_modification_number  federal_action_obligation  ...  \
# 0                                0                        0.0  ...
# 1                                0                 10152351.0  ...
# 2                                0                  3430262.0  ...
# 3                                0                   575305.0  ...
# 4                                0                  1314346.8  ...
#
#    highly_compensated_officer_2_name  highly_compensated_officer_2_amount  \
# 0                      DEBORAH  REED                             405673.0
# 1                                NaN                                  NaN
# 2                      DEBORAH  REED                             405673.0
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_3_name  highly_compensated_officer_3_amount  \
# 0              CHRISTOPHER  TRENHOLM                             382845.0
# 1                                NaN                                  NaN
# 2              CHRISTOPHER  TRENHOLM                             382845.0
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    highly_compensated_officer_4_name highly_compensated_officer_4_amount  \
# 0                     LISA  SCHWARTZ                            378414.0
# 1                                NaN                                 NaN
# 2                     LISA  SCHWARTZ                            378414.0
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    highly_compensated_officer_5_name highly_compensated_officer_5_amount  \
# 0                        ADAM  COYNE                            376235.0
# 1                                NaN                                 NaN
# 2                        ADAM  COYNE                            376235.0
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#                                usaspending_permalink last_modified_date
# 0  https://www.usaspending.gov/#/award/CONT_AWD_H...   10/18/2018 14:51
# 1  https://www.usaspending.gov/#/award/CONT_AWD_H...    7/17/2019 15:30
# 2  https://www.usaspending.gov/#/award/CONT_AWD_H...     5/21/2019 9:20
# 3  https://www.usaspending.gov/#/award/CONT_AWD_H...    3/14/2019 13:53
# 4  https://www.usaspending.gov/#/award/CONT_AWD_7...     4/1/2019 12:17
#
# [5 rows x 276 columns]

# %%
contracts.shape
# Out:
# (3787, 276)

# %% [markdown]
# My dataframe has 3,787 rows with 276 columns.

# %%
# This was a first attempt to subset the dataframe but this isn't what I really wanted.
# Implicit index with iloc #before comma is the rows and after comma is columns, with the ends excluded.
# df1.iloc[:2,:1 ]

#contracts_short = contracts.iloc[:,:6] #this pulls all the rows but only the first 5 columns. 
#I want to skip around and pull different columns.
#contracts_short.head()

# %%
#dataframe.filter([items,like,regex,axis])
# This filter command makes a subset of the dataframe with only the 19 variables/columns that I am interested in. 

contracts_short = contracts.filter(['contract_transaction_unique_key','parent_award_agency_name','total_dollars_obligated','base_and_exercised_options_value','action_date','period_of_performance_start_date','funding_sub_agency_name','recipient_name','recipient_doing_business_as_name','recipient_state_code','type_of_contract_pricing','product_or_service_code_description','naics_description','solicitation_procedures','type_of_set_aside','number_of_offers_received','multi_year_contract','veteran_owned_business','service_disabled_veteran_owned_business'])
contracts_short.head() # typed the individual column names to pull these into the smaller df called contracts_short
# Out:
#                      contract_transaction_unique_key  \
# 0  7530_7530_HHSM500T0016_P00004_HHSM500201400034I_0
# 1  7530_7530_HHSM500T0011_P00007_HHSM500200400007I_0
# 2  7530_7530_HHSM500T0016_P00006_HHSM500201400034I_0
# 3    7530_4732_HHSM500201700031G_P00006_GS35F328DA_0
# 4      7530_7530_75FCMC19F0002_0_HHSM500201600051I_0
#
#                      parent_award_agency_name  total_dollars_obligated  \
# 0  CENTERS FOR MEDICARE AND MEDICAID SERVICES                7235573.0
# 1  CENTERS FOR MEDICARE AND MEDICAID SERVICES               37419683.7
# 2  CENTERS FOR MEDICARE AND MEDICAID SERVICES               10665835.0
# 3                 FEDERAL ACQUISITION SERVICE                1807366.0
# 4  CENTERS FOR MEDICARE AND MEDICAID SERVICES                1314346.8
#
#    base_and_exercised_options_value action_date  \
# 0                               0.0  10/10/2018
# 1                        10152351.0   7/17/2019
# 2                         3430262.0   5/20/2019
# 3                          575305.0   3/13/2019
# 4                         1314346.8   3/28/2019
#
#   period_of_performance_start_date  \
# 0                  10/10/2018 0:00
# 1                   7/17/2019 0:00
# 2                   5/18/2019 0:00
# 3                   4/15/2019 0:00
# 4                   3/28/2019 0:00
#
#                       funding_sub_agency_name  \
# 0  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 1  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 2  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 4  CENTERS FOR MEDICARE AND MEDICAID SERVICES
#
#                       recipient_name recipient_doing_business_as_name  \
# 0  MATHEMATICA POLICY RESEARCH, INC.                              NaN
# 1     MAXIMUS FEDERAL SERVICES, INC.    MAXIMUS FEDERAL SERVICES, INC
# 2  MATHEMATICA POLICY RESEARCH, INC.                              NaN
# 3           ICF INCORPORATED, L.L.C.                              NaN
# 4                 CORMAC CORPORATION                              NaN
#
#   recipient_state_code type_of_contract_pricing  \
# 0                   DC      COST PLUS FIXED FEE
# 1                   VA         FIRM FIXED PRICE
# 2                   DC      COST PLUS FIXED FEE
# 3                   VA         FIRM FIXED PRICE
# 4                   VA         FIRM FIXED PRICE
#
#                  product_or_service_code_description  \
# 0                       SUPPORT- PROFESSIONAL: OTHER
# 1                       SUPPORT- PROFESSIONAL: OTHER
# 2                       SUPPORT- PROFESSIONAL: OTHER
# 3  SUPPORT- PROFESSIONAL: TECHNOLOGY SHARING/UTIL...
# 4                   IT AND TELECOM- SYSTEMS ANALYSIS
#
#                                    naics_description  \
# 0  RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...
# 1  ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 2  RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...
# 3               CUSTOM COMPUTER PROGRAMMING SERVICES
# 4                   COMPUTER SYSTEMS DESIGN SERVICES
#
#                       solicitation_procedures type_of_set_aside  \
# 0  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY               NaN
# 1  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY               NaN
# 2  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY               NaN
# 3  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY               NaN
# 4  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY               NaN
#
#    number_of_offers_received multi_year_contract veteran_owned_business  \
# 0                        6.0                 YES                      f
# 1                        2.0                  NO                      f
# 2                        6.0                 YES                      f
# 3                        1.0                 NaN                      f
# 4                        3.0                 YES                      f
#
#   service_disabled_veteran_owned_business
# 0                                       f
# 1                                       f
# 2                                       f
# 3                                       f
# 4                                       f

# %%
contracts_short.shape # This gives me the number of (rows, columns) in my shortened dataframe.
# Out:
# (3787, 19)

# %%
contracts_short.dtypes # This gives the data type for each variable (column).
# Out:
# contract_transaction_unique_key             object
# parent_award_agency_name                    object
# total_dollars_obligated                    float64
# base_and_exercised_options_value           float64
# action_date                                 object
# period_of_performance_start_date            object
# funding_sub_agency_name                     object
# recipient_name                              object
# recipient_doing_business_as_name            object
# recipient_state_code                        object
# type_of_contract_pricing                    object
# product_or_service_code_description         object
# naics_description                           object
# solicitation_procedures                     object
# type_of_set_aside                           object
# number_of_offers_received                  float64
# multi_year_contract                         object
# veteran_owned_business                      object
# service_disabled_veteran_owned_business     object
# dtype: object

# %% [markdown]
# The subset dataframe has different kinds of variables.
# The dataframe has strings, boolean (y/n and t/f), numeric, and date values.

# %%
contracts_short.describe() # Describe gives the stats for the numeric columns.
# Out:
#        total_dollars_obligated  base_and_exercised_options_value  \
# count             3.787000e+03                      3.366000e+03
# mean              5.174034e+07                      2.181596e+06
# std               2.118453e+08                      1.378403e+07
# min               0.000000e+00                     -2.568251e+07
# 25%               6.567154e+05                      0.000000e+00
# 50%               4.080377e+06                      0.000000e+00
# 75%               1.898408e+07                      9.271977e+05
# max               4.298741e+09                      5.497525e+08
#
#        number_of_offers_received
# count                3574.000000
# mean                   10.813374
# std                    28.010666
# min                     0.000000
# 25%                     1.000000
# 50%                     3.000000
# 75%                     5.750000
# max                   160.000000

# %%
contracts_short.describe(include="all") # This gives stats/counts on the non-numeric column types, too.
# Out:
#                           contract_transaction_unique_key  \
# count                                                3787
# unique                                               3787
# top     7530_7530_75FCMC18F0001_P00003_HHSM50020170003...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                           parent_award_agency_name  total_dollars_obligated  \
# count                                         2470             3.787000e+03
# unique                                           8                      NaN
# top     CENTERS FOR MEDICARE AND MEDICAID SERVICES                      NaN
# freq                                          1335                      NaN
# mean                                           NaN             5.174034e+07
# std                                            NaN             2.118453e+08
# min                                            NaN             0.000000e+00
# 25%                                            NaN             6.567154e+05
# 50%                                            NaN             4.080377e+06
# 75%                                            NaN             1.898408e+07
# max                                            NaN             4.298741e+09
#
#         base_and_exercised_options_value action_date  \
# count                       3.366000e+03        3787
# unique                               NaN         269
# top                                  NaN   9/12/2019
# freq                                 NaN          61
# mean                        2.181596e+06         NaN
# std                         1.378403e+07         NaN
# min                        -2.568251e+07         NaN
# 25%                         0.000000e+00         NaN
# 50%                         0.000000e+00         NaN
# 75%                         9.271977e+05         NaN
# max                         5.497525e+08         NaN
#
#        period_of_performance_start_date  \
# count                              3787
# unique                              332
# top                       2/1/2019 0:00
# freq                                 71
# mean                                NaN
# std                                 NaN
# min                                 NaN
# 25%                                 NaN
# 50%                                 NaN
# 75%                                 NaN
# max                                 NaN
#
#                            funding_sub_agency_name         recipient_name  \
# count                                         3787                   3787
# unique                                           1                    664
# top     CENTERS FOR MEDICARE AND MEDICAID SERVICES  THE MITRE CORPORATION
# freq                                          3787                     95
# mean                                           NaN                    NaN
# std                                            NaN                    NaN
# min                                            NaN                    NaN
# 25%                                            NaN                    NaN
# 50%                                            NaN                    NaN
# 75%                                            NaN                    NaN
# max                                            NaN                    NaN
#
#        recipient_doing_business_as_name recipient_state_code  \
# count                               195                 3778
# unique                               30                   46
# top                                 EDS                   VA
# freq                                 29                 1096
# mean                                NaN                  NaN
# std                                 NaN                  NaN
# min                                 NaN                  NaN
# 25%                                 NaN                  NaN
# 50%                                 NaN                  NaN
# 75%                                 NaN                  NaN
# max                                 NaN                  NaN
#
#        type_of_contract_pricing product_or_service_code_description  \
# count                      3787                                3787
# unique                       10                                 115
# top            FIRM FIXED PRICE        SUPPORT- PROFESSIONAL: OTHER
# freq                       1600                                1340
# mean                        NaN                                 NaN
# std                         NaN                                 NaN
# min                         NaN                                 NaN
# 25%                         NaN                                 NaN
# 50%                         NaN                                 NaN
# 75%                         NaN                                 NaN
# max                         NaN                                 NaN
#
#                                         naics_description  \
# count                                                3782
# unique                                                 89
# top     ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# freq                                                  727
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                            solicitation_procedures   type_of_set_aside  \
# count                                         3776                1710
# unique                                           7                   9
# top     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY  NO SET ASIDE USED.
# freq                                          2294                1043
# mean                                           NaN                 NaN
# std                                            NaN                 NaN
# min                                            NaN                 NaN
# 25%                                            NaN                 NaN
# 50%                                            NaN                 NaN
# 75%                                            NaN                 NaN
# max                                            NaN                 NaN
#
#         number_of_offers_received multi_year_contract veteran_owned_business  \
# count                 3574.000000                2690                   3787
# unique                        NaN                   2                      2
# top                           NaN                  NO                      f
# freq                          NaN                1764                   3601
# mean                    10.813374                 NaN                    NaN
# std                     28.010666                 NaN                    NaN
# min                      0.000000                 NaN                    NaN
# 25%                      1.000000                 NaN                    NaN
# 50%                      3.000000                 NaN                    NaN
# 75%                      5.750000                 NaN                    NaN
# max                    160.000000                 NaN                    NaN
#
#        service_disabled_veteran_owned_business
# count                                     3787
# unique                                       2
# top                                          f
# freq                                      3653
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN

# %%
print(contracts_short) #this shows me the first and last 5 rows
type(contracts_short)
# Out:
#                         contract_transaction_unique_key  \
# 0     7530_7530_HHSM500T0016_P00004_HHSM500201400034I_0
# 1     7530_7530_HHSM500T0011_P00007_HHSM500200400007I_0
# 2     7530_7530_HHSM500T0016_P00006_HHSM500201400034I_0
# 3       7530_4732_HHSM500201700031G_P00006_GS35F328DA_0
# 4         7530_7530_75FCMC19F0002_0_HHSM500201600051I_0
# ...                                                 ...
# 3782        7530_4730_75FCMC18F0065_P00001_GS07F9186S_0
# 3783      7530_-NONE-_HHSM500201700020P_P00001_-NONE-_0
# 3784               7530_-NONE-_75FCMC19C0004_0_-NONE-_0
# 3785      7530_-NONE-_HHSM500201300160P_P00002_-NONE-_0
# 3786      7530_-NONE-_HHSM500201300181P_P00001_-NONE-_0
#
#                         parent_award_agency_name  total_dollars_obligated  \
# 0     CENTERS FOR MEDICARE AND MEDICAID SERVICES               7235573.00
# 1     CENTERS FOR MEDICARE AND MEDICAID SERVICES              37419683.70
# 2     CENTERS FOR MEDICARE AND MEDICAID SERVICES              10665835.00
# 3                    FEDERAL ACQUISITION SERVICE               1807366.00
# 4     CENTERS FOR MEDICARE AND MEDICAID SERVICES               1314346.80
# ...                                          ...                      ...
# 3782                 FEDERAL ACQUISITION SERVICE                201018.62
# 3783                                         NaN                 96024.55
# 3784                                         NaN                537501.00
# 3785                                         NaN                100806.72
# 3786                                         NaN                  3500.00
#
#       base_and_exercised_options_value action_date  \
# 0                                 0.00  10/10/2018
# 1                          10152351.00   7/17/2019
# 2                           3430262.00   5/20/2019
# 3                            575305.00   3/13/2019
# 4                           1314346.80   3/28/2019
# ...                                ...         ...
# 3782                         131569.96   11/8/2018
# 3783                          -3975.45   11/8/2018
# 3784                         537501.00   11/8/2018
# 3785                           -685.76   11/8/2018
# 3786                         -14000.00   11/8/2018
#
#      period_of_performance_start_date  \
# 0                     10/10/2018 0:00
# 1                      7/17/2019 0:00
# 2                      5/18/2019 0:00
# 3                      4/15/2019 0:00
# 4                      3/28/2019 0:00
# ...                               ...
# 3782                   11/8/2018 0:00
# 3783                   11/8/2018 0:00
# 3784                  11/13/2018 0:00
# 3785                   11/8/2018 0:00
# 3786                   11/8/2018 0:00
#
#                          funding_sub_agency_name  \
# 0     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 1     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 2     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 4     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# ...                                          ...
# 3782  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3783  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3784  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3785  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3786  CENTERS FOR MEDICARE AND MEDICAID SERVICES
#
#                             recipient_name recipient_doing_business_as_name  \
# 0        MATHEMATICA POLICY RESEARCH, INC.                              NaN
# 1           MAXIMUS FEDERAL SERVICES, INC.    MAXIMUS FEDERAL SERVICES, INC
# 2        MATHEMATICA POLICY RESEARCH, INC.                              NaN
# 3                 ICF INCORPORATED, L.L.C.                              NaN
# 4                       CORMAC CORPORATION                              NaN
# ...                                    ...                              ...
# 3782  COMMUNICATIONS RESOURCE INCORPORATED                              NaN
# 3783          NATIONAL ACADEMY OF SCIENCES                              NaN
# 3784                  RADIANT INFOTECH LLC                              NaN
# 3785               DAVIS, AUDREY ROBINETTE                              NaN
# 3786           HAYMAKER TECHNOLOGIES, INC.                              NaN
#
#      recipient_state_code type_of_contract_pricing  \
# 0                      DC      COST PLUS FIXED FEE
# 1                      VA         FIRM FIXED PRICE
# 2                      DC      COST PLUS FIXED FEE
# 3                      VA         FIRM FIXED PRICE
# 4                      VA         FIRM FIXED PRICE
# ...                   ...                      ...
# 3782                   VA         FIRM FIXED PRICE
# 3783                   DC         FIRM FIXED PRICE
# 3784                   MD         FIRM FIXED PRICE
# 3785                   MD         FIRM FIXED PRICE
# 3786                   MD         FIRM FIXED PRICE
#
#                     product_or_service_code_description  \
# 0                          SUPPORT- PROFESSIONAL: OTHER
# 1                          SUPPORT- PROFESSIONAL: OTHER
# 2                          SUPPORT- PROFESSIONAL: OTHER
# 3     SUPPORT- PROFESSIONAL: TECHNOLOGY SHARING/UTIL...
# 4                      IT AND TELECOM- SYSTEMS ANALYSIS
# ...                                                 ...
# 3782  TECHNICAL REPRESENTATIVE- ALARM, SIGNAL, AND S...
# 3783                       SUPPORT- PROFESSIONAL: OTHER
# 3784    IT AND TELECOM- OTHER IT AND TELECOMMUNICATIONS
# 3785                     SUPPORT- MANAGEMENT: FINANCIAL
# 3786        ANTENNAS, WAVEGUIDES, AND RELATED EQUIPMENT
#
#                                       naics_description  \
# 0     RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...
# 1     ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 2     RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...
# 3                  CUSTOM COMPUTER PROGRAMMING SERVICES
# 4                      COMPUTER SYSTEMS DESIGN SERVICES
# ...                                                 ...
# 3782  OTHER APPAREL ACCESSORIES AND OTHER APPAREL MA...
# 3783  ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...
# 3784                   COMPUTER SYSTEMS DESIGN SERVICES
# 3785                          OTHER ACCOUNTING SERVICES
# 3786  WIRELESS TELECOMMUNICATIONS CARRIERS (EXCEPT S...
#
#                          solicitation_procedures  \
# 0     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 1     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 2     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 3     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 4     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# ...                                          ...
# 3782  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 3783                      SIMPLIFIED ACQUISITION
# 3784                             ONLY ONE SOURCE
# 3785                      SIMPLIFIED ACQUISITION
# 3786                      SIMPLIFIED ACQUISITION
#
#                      type_of_set_aside  number_of_offers_received  \
# 0                                  NaN                        6.0
# 1                                  NaN                        2.0
# 2                                  NaN                        6.0
# 3                                  NaN                        1.0
# 4                                  NaN                        3.0
# ...                                ...                        ...
# 3782  SMALL BUSINESS SET ASIDE - TOTAL                        2.0
# 3783                NO SET ASIDE USED.                        1.0
# 3784                 8(A) SOLE SOURCE                         1.0
# 3785                NO SET ASIDE USED.                        1.0
# 3786                NO SET ASIDE USED.                        1.0
#
#      multi_year_contract veteran_owned_business  \
# 0                    YES                      f
# 1                     NO                      f
# 2                    YES                      f
# 3                    NaN                      f
# 4                    YES                      f
# ...                  ...                    ...
# 3782                  NO                      f
# 3783                 NaN                      f
# 3784                  NO                      f
# 3785                 NaN                      f
# 3786                 NaN                      f
#
#      service_disabled_veteran_owned_business
# 0                                          f
# 1                                          f
# 2                                          f
# 3                                          f
# 4                                          f
# ...                                      ...
# 3782                                       f
# 3783                                       f
# 3784                                       f
# 3785                                       f
# 3786                                       f
#
# [3787 rows x 19 columns]
# pandas.core.frame.DataFrame

# %% [markdown]
# My variable total_dollars_obligated does not have any na's but just to be sure I will remove them.

# %%
#data_na = (data.dropna(subset=['Tax Returns']))
contracts_short_na = (contracts_short.dropna(subset=['total_dollars_obligated'])) #this removes the records that have na's in this variable.
print(contracts_short_na)
type(contracts_short_na)
# Out:
#                         contract_transaction_unique_key  \
# 0     7530_7530_HHSM500T0016_P00004_HHSM500201400034I_0
# 1     7530_7530_HHSM500T0011_P00007_HHSM500200400007I_0
# 2     7530_7530_HHSM500T0016_P00006_HHSM500201400034I_0
# 3       7530_4732_HHSM500201700031G_P00006_GS35F328DA_0
# 4         7530_7530_75FCMC19F0002_0_HHSM500201600051I_0
# ...                                                 ...
# 3782        7530_4730_75FCMC18F0065_P00001_GS07F9186S_0
# 3783      7530_-NONE-_HHSM500201700020P_P00001_-NONE-_0
# 3784               7530_-NONE-_75FCMC19C0004_0_-NONE-_0
# 3785      7530_-NONE-_HHSM500201300160P_P00002_-NONE-_0
# 3786      7530_-NONE-_HHSM500201300181P_P00001_-NONE-_0
#
#                         parent_award_agency_name  total_dollars_obligated  \
# 0     CENTERS FOR MEDICARE AND MEDICAID SERVICES               7235573.00
# 1     CENTERS FOR MEDICARE AND MEDICAID SERVICES              37419683.70
# 2     CENTERS FOR MEDICARE AND MEDICAID SERVICES              10665835.00
# 3                    FEDERAL ACQUISITION SERVICE               1807366.00
# 4     CENTERS FOR MEDICARE AND MEDICAID SERVICES               1314346.80
# ...                                          ...                      ...
# 3782                 FEDERAL ACQUISITION SERVICE                201018.62
# 3783                                         NaN                 96024.55
# 3784                                         NaN                537501.00
# 3785                                         NaN                100806.72
# 3786                                         NaN                  3500.00
#
#       base_and_exercised_options_value action_date  \
# 0                                 0.00  10/10/2018
# 1                          10152351.00   7/17/2019
# 2                           3430262.00   5/20/2019
# 3                            575305.00   3/13/2019
# 4                           1314346.80   3/28/2019
# ...                                ...         ...
# 3782                         131569.96   11/8/2018
# 3783                          -3975.45   11/8/2018
# 3784                         537501.00   11/8/2018
# 3785                           -685.76   11/8/2018
# 3786                         -14000.00   11/8/2018
#
#      period_of_performance_start_date  \
# 0                     10/10/2018 0:00
# 1                      7/17/2019 0:00
# 2                      5/18/2019 0:00
# 3                      4/15/2019 0:00
# 4                      3/28/2019 0:00
# ...                               ...
# 3782                   11/8/2018 0:00
# 3783                   11/8/2018 0:00
# 3784                  11/13/2018 0:00
# 3785                   11/8/2018 0:00
# 3786                   11/8/2018 0:00
#
#                          funding_sub_agency_name  \
# 0     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 1     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 2     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 4     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# ...                                          ...
# 3782  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3783  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3784  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3785  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 3786  CENTERS FOR MEDICARE AND MEDICAID SERVICES
#
#                             recipient_name recipient_doing_business_as_name  \
# 0        MATHEMATICA POLICY RESEARCH, INC.                              NaN
# 1           MAXIMUS FEDERAL SERVICES, INC.    MAXIMUS FEDERAL SERVICES, INC
# 2        MATHEMATICA POLICY RESEARCH, INC.                              NaN
# 3                 ICF INCORPORATED, L.L.C.                              NaN
# 4                       CORMAC CORPORATION                              NaN
# ...                                    ...                              ...
# 3782  COMMUNICATIONS RESOURCE INCORPORATED                              NaN
# 3783          NATIONAL ACADEMY OF SCIENCES                              NaN
# 3784                  RADIANT INFOTECH LLC                              NaN
# 3785               DAVIS, AUDREY ROBINETTE                              NaN
# 3786           HAYMAKER TECHNOLOGIES, INC.                              NaN
#
#      recipient_state_code type_of_contract_pricing  \
# 0                      DC      COST PLUS FIXED FEE
# 1                      VA         FIRM FIXED PRICE
# 2                      DC      COST PLUS FIXED FEE
# 3                      VA         FIRM FIXED PRICE
# 4                      VA         FIRM FIXED PRICE
# ...                   ...                      ...
# 3782                   VA         FIRM FIXED PRICE
# 3783                   DC         FIRM FIXED PRICE
# 3784                   MD         FIRM FIXED PRICE
# 3785                   MD         FIRM FIXED PRICE
# 3786                   MD         FIRM FIXED PRICE
#
#                     product_or_service_code_description  \
# 0                          SUPPORT- PROFESSIONAL: OTHER
# 1                          SUPPORT- PROFESSIONAL: OTHER
# 2                          SUPPORT- PROFESSIONAL: OTHER
# 3     SUPPORT- PROFESSIONAL: TECHNOLOGY SHARING/UTIL...
# 4                      IT AND TELECOM- SYSTEMS ANALYSIS
# ...                                                 ...
# 3782  TECHNICAL REPRESENTATIVE- ALARM, SIGNAL, AND S...
# 3783                       SUPPORT- PROFESSIONAL: OTHER
# 3784    IT AND TELECOM- OTHER IT AND TELECOMMUNICATIONS
# 3785                     SUPPORT- MANAGEMENT: FINANCIAL
# 3786        ANTENNAS, WAVEGUIDES, AND RELATED EQUIPMENT
#
#                                       naics_description  \
# 0     RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...
# 1     ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 2     RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...
# 3                  CUSTOM COMPUTER PROGRAMMING SERVICES
# 4                      COMPUTER SYSTEMS DESIGN SERVICES
# ...                                                 ...
# 3782  OTHER APPAREL ACCESSORIES AND OTHER APPAREL MA...
# 3783  ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...
# 3784                   COMPUTER SYSTEMS DESIGN SERVICES
# 3785                          OTHER ACCOUNTING SERVICES
# 3786  WIRELESS TELECOMMUNICATIONS CARRIERS (EXCEPT S...
#
#                          solicitation_procedures  \
# 0     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 1     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 2     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 3     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 4     SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# ...                                          ...
# 3782  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 3783                      SIMPLIFIED ACQUISITION
# 3784                             ONLY ONE SOURCE
# 3785                      SIMPLIFIED ACQUISITION
# 3786                      SIMPLIFIED ACQUISITION
#
#                      type_of_set_aside  number_of_offers_received  \
# 0                                  NaN                        6.0
# 1                                  NaN                        2.0
# 2                                  NaN                        6.0
# 3                                  NaN                        1.0
# 4                                  NaN                        3.0
# ...                                ...                        ...
# 3782  SMALL BUSINESS SET ASIDE - TOTAL                        2.0
# 3783                NO SET ASIDE USED.                        1.0
# 3784                 8(A) SOLE SOURCE                         1.0
# 3785                NO SET ASIDE USED.                        1.0
# 3786                NO SET ASIDE USED.                        1.0
#
#      multi_year_contract veteran_owned_business  \
# 0                    YES                      f
# 1                     NO                      f
# 2                    YES                      f
# 3                    NaN                      f
# 4                    YES                      f
# ...                  ...                    ...
# 3782                  NO                      f
# 3783                 NaN                      f
# 3784                  NO                      f
# 3785                 NaN                      f
# 3786                 NaN                      f
#
#      service_disabled_veteran_owned_business
# 0                                          f
# 1                                          f
# 2                                          f
# 3                                          f
# 4                                          f
# ...                                      ...
# 3782                                       f
# 3783                                       f
# 3784                                       f
# 3785                                       f
# 3786                                       f
#
# [3787 rows x 19 columns]
# pandas.core.frame.DataFrame

# %% [markdown]
# Since my number of rows did not change (3787) I know that no records were removed due to na's.

# %% [markdown]
# I will continue with some exploratory data analysis (EDA) using matplotlib.

# %%
# This didn't work out quite as planned so i've abandoned this method.
#import matplotlib as mpl
#import matplotlib.pyplot as plt
#x = np.random.randn(1000)
#plt.hist(x); # or 
#plt.hist(x, bins=30,normed=True,alpha=0.5,histtype='stpfilled',color='steelblue',edgecolor='none');

#offers = contracts_short.filter(['number_of_offers_received'])
#offers = offers.fillna(0)
#offers = contracts_short.pd('number_of_offers_received')
#plt.hist(offers)
#plt.show()

# %% [markdown]
# This will give me a histogram of the number of offers for each contract.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
_ = plt.hist(contracts_short.number_of_offers_received)
_ = plt.xlabel('Number of Offers sent to CMS for each Contract FY19')
_ = plt.ylabel('Number of Contracts')
# Out:
# C:\Users\Jennifer\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Jennifer\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# I will use seaborn styling to show this histogram again.

# %%
import seaborn as sns
sns.set()
_ = plt.hist(contracts_short.number_of_offers_received)
_ = plt.xlabel('Number of Offers sent to CMS for each Contract FY19')
_ = plt.ylabel('Number of Contracts')

# %% [markdown]
# I will make the histogram again but change the bin number.

# %%
_ = plt.hist(contracts_short.number_of_offers_received, bins=100)
_ = plt.xlabel('Number of Offers sent to CMS for each Contract FY19')
_ = plt.ylabel('Number of Contracts')

# %% [markdown]
# This will give me a histogram of the Total Dollars Obligated for the fiscal year.

# %%
plt.hist(contracts_short.total_dollars_obligated)
plt.xlabel('Total Dollars Obligated FY19')
plt.ylabel('Number of Contracts')
# Out:
# Text(0, 0.5, 'Number of Contracts')

# %% [markdown]
# This will give me a histogram of the Total Dollars for the Base Year and already Exercised Options.

# %%
plt.hist(contracts_short.base_and_exercised_options_value)
plt.xlabel('Total Dollars - Base Year and Exercised Options')
plt.ylabel('Number of Contracts')
# Out:
# Text(0, 0.5, 'Number of Contracts')

# %% [markdown]
# Going back to the Total Dollars Obligated for the FY19, I will try different bin values to make the histogram reveal more about the data.

# %%
sns.set()
plt.hist(contracts_short.total_dollars_obligated,bins=50)
plt.xlabel('Total Dollars Obligated FY19')
plt.ylabel('Number of Contracts')
# Out:
# Text(0, 0.5, 'Number of Contracts')

# %% [markdown]
# # Bootstrapping
# I will need to pull just the one variable out.
# I will need to take random samples of my records for the variable_total_dollars obligated and append the samples onto the data.

# %%
#mdtaxrt = data_na['Tax Returns']
#type(mdtaxrt)
obligated = contracts_short['total_dollars_obligated'] # this keeps just the one variable.
print(obligated)
type(obligated)
# Out:
# 0        7235573.00
# 1       37419683.70
# 2       10665835.00
# 3        1807366.00
# 4        1314346.80
#            ...
# 3782      201018.62
# 3783       96024.55
# 3784      537501.00
# 3785      100806.72
# 3786        3500.00
# Name: total_dollars_obligated, Length: 3787, dtype: float64
# pandas.core.series.Series

# %%
data_sample = np.random.choice(obligated,size = 100) # this is just a random sample of 100 records
np.mean(data_sample) # the mean of my one sample
# Out:
# 22850075.3189

# %%
np.median(data_sample)
# Out:
# 2938870.34

# %%
np.std(data_sample)
# Out:
# 57393061.48678661

# %%
n_size = int(len(obligated) * 0.75) # this tells me how many records I need in my training set (75% of 3787)
print(n_size)
# Out:
# 2840

# %%
from sklearn.utils import resample #we use the resample 
n_iterations = 2000

boot_samples = list()
mean_boot_samples = list()
median_boot_samples =list()

for i in range(n_iterations): #this does the bootstrapping
    boot_sample = resample(obligated, n_samples = n_size) # this stores the samples as a list?
    boot_samples.append(boot_sample) # this appends the new sample onto the rest
    
    mean_boot_samples.append(np.mean(boot_sample)) #calculates the mean of the sample and appends it to the list
    
    median_boot_samples.append(np.median(boot_sample)) #calculates the median of the sample and appends it to the list
    
print("The Length of the boot_samples is: " + str(len(boot_samples)))
print("The mean of the bootstrapped data is: " + str(np.mean(mean_boot_samples)))
print("The median of the bootstrapped data is: " + str(np.median(median_boot_samples)))
# Out:
# The Length of the boot_samples is: 2000
# The mean of the bootstrapped data is: 51812067.70311329
# The median of the bootstrapped data is: 4084706.6975

# %% [markdown]
# # Was that all that was required for the bootstrapping?
# Do I need to do the next 2 cells? to get more samples? or is that all done in the for loop above?

# %%
#resample_1 = obligated.sample(100, replace=True)
#resample_1.median()
# Out:
# 3994809.5

# %%
#resample_2 = obligated.sample(100, replace=True)
#resample_2.median()
# Out:
# 3546971.0

# %% [markdown]
# # I am lost as to what to do here and don't know how to fix my errors.

# %%
resamples_medians = pd.Series(index=np.arange(1000))
for i in range(1000): 
              resamples_medians[i] = obligated(100, replace=True).median()

print(resamples_medians.median())
print(resamples_medians.mean())
print(resamples_medians.quantile(0.025))
print(resamples_medians.quantile(0.975))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-3b8ee6605da0> in <module>
#       1 resamples_medians = pd.Series(index=np.arange(1000))
#       2 for i in range(1000):
# ----> 3               resamples_medians[i] = obligated(100, replace=True).median()
#       4
#       5 print(resamples_medians.median())
#
# TypeError: 'Series' object is not callable

# %% [markdown]
# train_dataset = X_train.copy()
#
# train_dataset.insert(0,"WAGE", y_train)
#
# _ = sns.pairplot(train_dataset, kind='reg', diag_kind = 'kde')
